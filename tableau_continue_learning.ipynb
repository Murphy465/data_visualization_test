# %% [markdown]
# ---
# title: 🚀 Continue Learning Tableau
# subject: Tutorial
# format:
#   html:
#     toc: true
#     toc-expand: 2
#     toc-title: CONTENTS
# bibliography:
#   - references.bib
# ---

# %% [markdown]
# Congratulations on completing the Tableau for Research workshop! Here are some recommendations to help you continue your Tableau learning journey:
#
# # Join a community
#
# Did you know The Ohio State University has an active __[Tableau User Group](https://teams.microsoft.com/l/channel/19%3A296eef34292a46bfb636ccc686917037%40thread.tacv2/Tips%20and%20Tricks%20(non-Tableau%20related)?groupId=8bc3e6e4-a6a6-4d14-8e35-ed41e470e085&tenantId=eb095636-1052-4895-952b-1ff9df1d1121)__? Join a vibrant bunch of campus Tableau enthusiasts who meet regularly to:
#
# - Share tips and tricks
# - Explore new ways to visualize data
# - Prepare for Tableau certification exams
#
# The group's **Microsoft Teams channel** has over 200 members and is a great place to ask questions, get feedback, and stay inspired.
#
# 👉 **Join directly with the code: e880cmx**
#
# # Take another training class
#
# You already know that completing a training class can help you pause your daily responsibilities to learn a new skill. There are several online, in-person, and hybrid training opportunities available to you. Keep your eye on the __[Research Commons workshop offerings](https://library.osu.edu/events-0)__ – or try a __[LinkedIn Learning](https://hrconnection.osu.edu/esc?id=emp_taxonomy_topic&topic_id=d9659da0338c12506b4fbbf36d5c7b88)__ tutorial.
#
# # Read! Read! Read!
#
# Search University Libraries __[catalog](https://search.library.osu.edu/discovery/search?query=any,contains,data%20visualization&tab=LibraryCatalog&search_scope=MyInstitution&vid=01OHIOLINK_OSU:OSU&offset=0)__ for data visualization books, videos, and more. Follow respected __[blogs](https://www.flerlagetwins.com/)__ by Tableau teachers and innovators. Bookmark effective or innovative data visualizations you find on websites that resonate with you.
#
# # Practice, practice, practice
#
# A master musician, artist, or chefs practices his or her craft. Set aside time each week to practice Tableau.
#
# - Try weekly challenges like __[MakeoverMonday](https://makeovermonday.co.uk/)__
# - Join a __[Tableau Community Project](https://www.tableau.com/community/community-projects)__.
# - Recreate visualizations you admire to learn new techniques
#
# # Follow Tableau Public
#
# Get inspired by how others are using Tableau in creative and impactful ways. Explore the __[Viz of the Day](https://public.tableau.com/app/discover/viz-of-the-day)__ on Tableau Public to see what’s possible—and spark your own ideas.
